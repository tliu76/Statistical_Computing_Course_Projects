# %%
# primitive datatypes and operators

1+1

5 //3
-5.0 //3.0

10.0 /3
# Out:
# 3.3333333333333335

# %%
7 % 3
-7 % 3\

2**3

1+3*2
# Out:
# 7

# %%
True + True
False -5


bool(0)
bool(2)

0 and 2
# Out:
# 0

# %%
print("I'm Python. Nice to meet to you!")

li = []
# Out:
# I'm Python. Nice to meet to you!

# %%
li = []

other_li = [4, 5, 6]

li.append(1)
li.append(2)
li.pop()
li.append(3)

# %%
print(li)
# Out:
# [4, 5, 6]

# %%
li[-1]
# Out:
# 3

# %%
li2 = li[:]
del li[1]

# %%
li.remove(1)

# %%
li.extend(other_li)

# %%
len(li)
# Out:
# 3

# %%
tup=(1,2,3)
tup[0]
# Out:
# 1

# %%
type(())
# Out:
# tuple

# %%
empty_dict = {}

# %%
filled_dict = {"one": 1, "two": 2, "three": 3}

# %%
valid_dict = {(1,2,3):[1,2,3]}

# %%
filled_dict["one"]
# Out:
# 1

# %%
some_var = 5
for animal in ["dog", "cat", "mouse"]:
    # You can use format() to interpolate formatted strings
    print("{} is a mammal".format(animal))
# Out:
# dog is a mammal
# cat is a mammal
# mouse is a mammal

# %%
for i in range(4):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
for i in range(4, 8):
    print(i)
# Out:
# 4
# 5
# 6
# 7

# %%
for i in range(4, 8, 2):
    print(i)
# Out:
# 4
# 6

# %%
animals = ["dog", "cat", "mouse"]
for i, value in enumerate(animals):
    print(i, value)
# Out:
# 0 dog
# 1 cat
# 2 mouse

# %%
x = 0
while x < 4:
    print(x)
    x += 1
# Out:
# 0
# 1
# 2
# 3

# %%
try:
    user_input = int(input("Enter a number: "))
    print(10 / user_input)  # This may raise a ZeroDivisionError
except ValueError:
    print("Invalid input! Please enter a valid number.")
except ZeroDivisionError:
    print("Division by zero is not allowed.")
else:
    print("Successful execution!")
finally:
    print("End of program.")
# Out:
# Enter a number: 1
# 10.0
# Successful execution!
# End of program.

# %%
with open("myfile.txt") as f:
    for line in f:
        print(line)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-67-dbca4fa73c20> in <cell line: 0>()
# ----> 1 with open("myfile.txt") as f:
#       2     for line in f:
#       3         print(line)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'myfile.txt'

# %%
import json
with open("myfile2.txt", "w") as file:
    file.write(json.dumps(contents))  # writes an object to a file
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-876a873cb4ef> in <cell line: 0>()
#       1 import json
#       2 with open("myfile2.txt", "w") as file:
# ----> 3     file.write(json.dumps(contents))  # writes an object to a file
#
# NameError: name 'contents' is not defined

# %%
def set_global_x(num):
    # global indicates that particular var lives in the global scope
    global x
    print(x)   # => 5
    x = num    # global var x is now set to 6
    print(x)   # => 6
